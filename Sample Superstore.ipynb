# %%
#import libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %%
# csv file
sp=pd.read_csv('SampleSuperstore.csv')
sp
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# first five rows
sp.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# last five rows
sp.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
sp.shape
# Out:
# (9994, 13)

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# description
sp.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# creating copy of dataset
sp1=sp.copy()
sp1.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
no_of_states=sp1['State'].nunique()
print("There are %d states in this dataset. " %no_of_states)
# Out:
# There are 49 states in this dataset.

# %%
no_of_cities=sp1['City'].nunique()
print("There are %d cities in this dataset. " %no_of_cities)
# Out:
# There are 531 cities in this dataset.

# %%
no_of_subcategory=sp1['Sub-Category'].nunique()
print("There are %d Sub-Category in this dataset. " %no_of_subcategory)
# Out:
# There are 17 Sub-Category in this dataset.

# %% [markdown]
# # Find out duplicate values

# %%
# duplicate value count
duplicate_values=sp1.duplicated().value_counts()
duplicate_values
# Out:
# False    9977
# True       17
# dtype: int64

# %%
# visualization of duplicate values
plt.figure(figsize=(14,7))
plt.bar(duplicate_values.index.astype(str),duplicate_values.values)
plt.xlabel("Duplicate Status")
plt.ylabel("Count")
plt.title("Duplicate Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# droping duplicate values
sp1=sp1.drop_duplicates()
sp1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sp1.shape
# Out:
# (9977, 13)

# %% [markdown]
# # Missing values

# %%
# missing value count
missing_value=sp1.isnull().sum().sort_values(ascending=False)

# %%
missing_value
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# columns
sp1.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
sp.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
print(sp1.apply(lambda col:col.unique()))
# Out:
# Ship Mode       [Second Class, Standard Class, First Class, Sa...
# Segment                        [Consumer, Corporate, Home Office]
# Country                                           [United States]
# City            [Henderson, Los Angeles, Fort Lauderdale, Conc...
# State           [Kentucky, California, Florida, North Carolina...
# Postal Code     [42420, 90036, 33311, 90032, 28027, 98103, 761...
# Region                               [South, West, Central, East]
# Category                 [Furniture, Office Supplies, Technology]
# Sub-Category    [Bookcases, Chairs, Labels, Tables, Storage, F...
# Sales           [261.96, 731.94, 14.62, 957.5775, 22.368, 48.8...
# Quantity          [2, 3, 5, 7, 4, 6, 9, 1, 8, 14, 11, 13, 10, 12]
# Discount        [0.0, 0.45, 0.2, 0.8, 0.3, 0.5, 0.7, 0.6, 0.32...
# Profit          [41.9136, 219.582, 6.8714, -383.031, 2.5164, 1...
# dtype: object

# %%
sp1=sp.drop_duplicates()
sp1
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Data Visualization

# %%
ship_mode_counts=sp1['Ship Mode'].value_counts().reset_index().rename(columns={'index':'Ship Mode','Ship Mode':'ship_mode_counts'})
ship_mode_counts
# Out:
#         Ship Mode  ship_mode_counts
# 0  Standard Class              5955
# 1    Second Class              1943
# 2     First Class              1537
# 3        Same Day               542

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=ship_mode_counts['Ship Mode'],y=ship_mode_counts['ship_mode_counts'],order=ship_mode_counts['Ship Mode'])
plt.xlabel("Ship Mode",fontsize=15)
plt.ylabel("Ship Mode Count",fontsize=15)
plt.title("Visualization of ship mode",fontsize=20)
plt.show()

# %%
preferred_segment_type=sp1['Segment'].value_counts()
preferred_segment_type
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=sp1['Segment'],order=preferred_segment_type.index)
plt.xlabel("Type of segment",fontsize=15)
plt.ylabel("Count of segment",fontsize=15)
plt.title("Preferred Segment Type",fontsize=20)
plt.show()

# %%
highest_sale=sp1.groupby('Category')['Sales'].mean().reset_index()
highest_sale
# Out:
#           Category       Sales
# 0        Furniture  350.002981
# 1  Office Supplies  119.550107
# 2       Technology  452.709276

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=highest_sale['Category'],y=highest_sale['Sales'])
plt.xlabel("Category",fontsize=15)
plt.ylabel("Sales",fontsize=15)
plt.title("Categorywise Sales",fontsize=20)
plt.show()

# %%
# create a loss dataframe
loss_sp=sp1[sp1['Profit']<0]
loss_sp
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
loss_sp.shape
# Out:
# (1869, 13)

# %%
loss_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1869 entries, 3 to 9962
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     1869 non-null   object
#  1   Segment       1869 non-null   object
#  2   Country       1869 non-null   object
#  3   City          1869 non-null   object
#  4   State         1869 non-null   object
#  5   Postal Code   1869 non-null   int64
#  6   Region        1869 non-null   object
#  7   Category      1869 non-null   object
#  8   Sub-Category  1869 non-null   object
#  9   Sales         1869 non-null   float64
#  10  Quantity      1869 non-null   int64
#  11  Discount      1869 non-null   float64
#  12  Profit        1869 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 204.4+ KB

# %%
# total loss
total_loss=np.negative(loss_sp['Profit'].sum())
print('Total_loss=%.2f' %total_loss)
# Out:
# Total_loss=156112.99

# %%
loss_in_segment=sp1.groupby('Segment').sum().reset_index()
loss_in_segment
# Out:
# C:\Users\win\AppData\Local\Temp\ipykernel_8684\3230139387.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   loss_in_segment=sp1.groupby('Segment').sum().reset_index()
#        Segment  Postal Code         Sales  Quantity  Discount       Profit
# 0     Consumer    288269634  1.160833e+06     19497    820.51  134007.4413
# 1    Corporate    164108306  7.060701e+05     11591    476.85   91954.9798
# 2  Home Office     97903137  4.292927e+05      6732    261.83   60279.0015

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=loss_in_segment['Segment'],y=loss_in_segment['Profit'], data=loss_in_segment['Segment'])
plt.xlabel("Segment",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.title("Segmentwise Loss")
plt.show()

# %%
loss_in_state=loss_sp.groupby('State').sum().reset_index().sort_values('Profit', ascending=True).head(10)
loss_in_state
# Out:
# C:\Users\win\AppData\Local\Temp\ipykernel_8684\3540804574.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   loss_in_state=loss_sp.groupby('State').sum().reset_index().sort_values('Profit', ascending=True).head(10)
#              State  Postal Code        Sales  Quantity  Discount      Profit
# 20           Texas     37388572  102656.4568      1855    263.24 -36813.1875
# 15            Ohio      9144155   49526.2520       776     98.40 -21737.9414
# 17    Pennsylvania      5291815   75792.2320       993    128.10 -21602.8515
# 6         Illinois     15419174   38622.6380       945    143.10 -19495.4605
# 14  North Carolina      1909180   28226.5400       300     34.40 -11557.9854
# 2         Colorado      5300931   12833.2140       269     34.40  -8900.9048
# ...

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=loss_in_state['State'],y=loss_in_state['Profit'],data=loss_in_state['State'])
plt.xlabel("Loss",fontsize=15)
plt.ylabel("State",fontsize=15)
plt.title("Statewise loss")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(sp1.corr(),annot=True)
plt.title('Correlation of the columns')
plt.show()
# Out:
# C:\Users\win\AppData\Local\Temp\ipykernel_8684\397334159.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sp1.corr(),annot=True)
